# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay722187-web/lernpyt/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('vvv')
# Out:
# vvv
