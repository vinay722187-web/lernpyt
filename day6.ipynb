# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay722187-web/lernpyt/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
  name ='nikhil'
  roll_no=123

s=Student() #s=object
print(s.name)  #name=atribute
# Out:
# nikhil

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name=name
    self.roll_no=roll_no
s=Student("nikhil",123)
print(s.name)
# Out:
# nikhil

# %%
class Student:
  def __init__(name,n,roll_no):
    name.n=n
    name.roll_no=roll_no
s=Student("nikhil",123)
print(s.n)
# Out:
# nikhil

# %%
class Student:
  def __init__(self,name,roll_no,age):
    self.name=name
    self.roll_no=roll_no
    self.age=age
s=Student("nikhil",12,20)
print(s.age,s.name)
print(s.roll_no)
# Out:
# 20 nikhil
# 12

# %%
class Student:
  def __init__(this,name,roll_no,age):
    this.name=name
    this.age=age
    this.roll_no=roll_no

s=Student(name='nikhil',roll_no=123,age=30)
print(s.name,s.age,s.roll_no)
# Out:
# nikhil 30 123

# %%
class Student:
  def __init__(this,name='dd',roll_no=222,age=None):
    this.name=name
    this.roll_no=roll_no
    this.age=age

s=Student('nikhil',123)
print(s.name,s.age,s.roll_no)

s1=Student('raj',1111,44)
print(s1.name,s1.roll_no,s1.age)

s2=Student()
print(s2.name,s2.age,s2.roll_no)
# Out:
# nikhil None 123
# raj 1111 44
# dd None 222

# %%
class Student:
  def __init__(this,*argspp):
    # print(type(args))  #args=tuple | immutable
    # print(args)  #tupplr formt
    this.vv=argspp

s=Student('nikhil',123,20)
print(s.vv[0],s.vv[1],s.vv[2],)
# Out:
# nikhil 123 20

# %%
class Student:
  def __init__(self,*args):
    self.data=args

s=Student(['nikhil','raj','arya'])
print(s.data[0][0],)
# Out:
# nikhil

# %%
class Student:
  def __init__(self,*args):
    self.data=args

s=Student({'user':['nikhil',"raj","abhi","vin"]},{'add.':{"hom_town":'kukus','office':'japur'}})
print(s.data[0]['user'])
print(s.data[1]['add.']['hom_town'])
print(s.data[1]['add.']['office'])
# Out:
# ['nikhil', 'raj', 'abhi', 'vin']
# kukus
# japur

# %%
class Student:
  def __init__(self,name,rlno):
    self.name=name
    self.rlno=rlno

  def getName(self):
     print(self.name)


  def updateName(self):
    self.name='hello'
    print(self.name)

  def deleteName(self):
    del self.name
    print(self.name)

  def createName(self):
    self.full_name="raj"
    print(self.full_name)

s=Student('nikhil',123)
s.createName()
# Out:
# raj

# %%
class Student:
  def __init__(self,name,roll_no):
    print("auto start")
    self.name = name
    self.roll_no = roll_no
  # get
  def updateName(self,name=None): # default value -> none
    if name != None:
      self.name = name
    print(self.name)


inst = Student("nikhil",123)
inst.updateName("rajendra")

inst1 = Student("abhishek",321)
inst1.updateName()
# Out:
# auto start
# rajendra
# auto start
# abhishek

# %%
# inheritance
class Student:
  def __init__(self, name,rlno):
    self.name=name
    self.rlno=rlno
  def getdata(self):
    print(self.name,self.rlno)

s=Student('nikhil',123)
s.getdata()

class Address(Student):
  def __init__(self,name,rlno,city,state):
    self.city=city
    self.state=state

    super().__init__(name,rlno)
    # extra wreitten
    # self.name=name
    # self.rlno=rlno

  def getAddress(self):
    print(self.city,self.state)

a=Address('nikhil',123,'jaipur','rajsthn')
a.getAddress()
a.getdata()
# Out:
# nikhil 123
# jaipur rajsthn
# nikhil 123
