# %% [markdown]
# <a href="https://colab.research.google.com/github/vinay722187-web/lernpyt/blob/main/day77.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class User1:
  def __init__(self,pen,pencil):
    self.pen=pen
    self.pencil=pencil
  def pen(self):
    print('pen is wrkng:',self.pen)
  def pencil(self):
    print('pencil is wtrkng;',self.pencil)

class User2(user1):
  def __init__(self,pen,pencil,eraser):
    self.pen=pen
    self.pencil=pencil
    self.eraser=eraser

  u=user2('blue','balck','doms')
  u.penget()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1207/2924438342.py in <cell line: 0>()
#       8     print('pencil is wtrkng;',self.pencil)
#       9
# ---> 10 class User2(user1):
#      11   def __init__(self,pen,pencil,eraser):
#      12     self.pen=pen
#
# NameError: name 'user1' is not defined
